# %% [markdown]
# # Nils Kelley

# %% [markdown]
# ## Research question/interests
#
# #### Question 1
# What is the correlation between alcohol consumption and academic success?
#
# #### Question 2
# Question 2: What distributions or relationships can be mapped to the key factors that infleunce academic success?
#
# #### Interest
# I am interested in the correlation between what attributes are the main factors of success and failure for students. In particular, if the data will show a consistent trend between both of the courses.

# %% [markdown]
# #### Code:

# %%
# Importing pandas
import pandas as pd

# %%
# Reading and displaying the CVS File for Math through path
df_math = pd.read_csv('../data/raw/Maths_formatted.csv', engine='python', on_bad_lines='skip')
display(df_math)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
# 395     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 396     MS   M   19       R     GT3       T     1     1     other  services
#
# ...

# %%
# Reading and displaying the CVS File for Portuguese through path
df_portuguese = pd.read_csv('../data/raw/Portuguese_formatted.csv', engine='python', on_bad_lines='skip')
display(df_portuguese)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
# 649     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 650     MS   F   16       R     GT3       T     2     2     other     other
#
# ...

# %% [markdown]
# ## Milestone 3: Data Analysis

# %% [markdown]
# ### I know it varies a little from my research questions, but for Task 1, I will be analyzing the coorelation between a Math student's freetime and their absences.
#
# #### I chose to keep my research question up there because I will likely use them moving forward. It's just that this question intrigued me upon reviewing the data set.

# %% [markdown]
# ### Task1:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('../data/raw/Maths_formatted.csv', engine='python', on_bad_lines='skip')
df2 = pd.read_csv('../data/raw/Portuguese_formatted.csv', engine='python', on_bad_lines='skip')

plt.figure()
print("First four graphs are Math. Final four for Portuguese")
#Freetime X Absences
df.plot.scatter(x='freetime', y='absences')
#Final Grade X Absences
df.plot.scatter(x='G3', y='absences')
#Freetime X Final Grade
df.plot.scatter(x='freetime', y='G3')
#Weekend ALC Use X Absences
df.plot.scatter(x='Walc', y='G3')

#Freetime X Absences
df2.plot.scatter(x='freetime', y='absences')
#Final Grade X Absences
df2.plot.scatter(x='G3', y='absences')
#Freetime X Final Grade
df2.plot.scatter(x='freetime', y='G3')
#Weekend ALC Use X Absences
df2.plot.scatter(x='Walc', y='G3')
# Out:
# First four graphs are Math. Final four for Portuguese
# <AxesSubplot: xlabel='Walc', ylabel='G3'>

# %% [markdown]
# #### Findings from EDA (Task 1):
#
# -The findings from the graphs tell us two main things:

# %% [markdown]
# (1): There is a correlation between the patterns of students between the two courses, AND

# %% [markdown]
# (2): That Less Absences <-> Less FreeTime <-> Higher G3(final grade) <-> Less Walc (weekend alcohol consumption)

# %% [markdown]
# ## (Milestone 3 -Task 2) - Set up an "Analysis Pipeline"

# %%
import pandas as pd
import numpy as np
import seaborn as sp
import matplotlib.pyplot as plt


# 1: Load Data
dfm = pd.read_csv('../data/raw/Maths_formatted.csv', engine='python', on_bad_lines='skip')
dfp = pd.read_csv('../data/raw/Portuguese_formatted.csv', engine='python', on_bad_lines='skip')

# 2&3: Cleaning through the Processing 
grouped = dfm.groupby('G3').mean()
grouped2 = dfp.groupby('G3').mean()

# Plotting Data to show what the distibution of things is for different varities of G3 (avg) for (1) - Math and (2) - Portuguese
plt.figure()
grouped.plot.barh(stacked=True)
grouped2.plot.barh(stacked=True)

# 4: Wrangling Data 
# fm = Highest and Lowest scoring students for Math
fm = pd.merge(df, grouped, how='inner')
display(fm)
# Out:
# C:\Users\nilsk\AppData\Local\Temp\ipykernel_15816\790674490.py:12: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = dfm.groupby('G3').mean()
# C:\Users\nilsk\AppData\Local\Temp\ipykernel_15816\790674490.py:13: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped2 = dfp.groupby('G3').mean()
# C:\Users\nilsk\AppData\Local\Temp\ipykernel_15816\790674490.py:22: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   fm = pd.merge(df, grouped, how='inner')
# ...

# %% [markdown]
# ## (Milestone 3 - Task 3): Method Chaining and Python Programs

# %% [markdown]
# Task 3 - Step 1:

# %%
import pandas as pd
from project_functions3 import load_and_process


load_and_process('../data/raw/Portuguese_formatted.csv')
# Out:
#     School Sex  Age Address  studytime activities internet  Freetime  Go_Out  \
# 0       GP   F   18       U          2         no       no         3       4
# 1       GP   F   17       U          2         no      yes         3       3
# 2       GP   F   15       U          2         no      yes         3       2
# 3       GP   F   15       U          3        yes      yes         2       2
# 4       GP   F   16       U          2         no       no         3       2
# ..     ...  ..  ...     ...        ...        ...      ...       ...     ...
# 646     MS   F   18       U          2        yes       no         1       1
# 647     MS   M   17       U          1         no      yes         4       5
# 648     MS   M   18       R          1         no      yes         4       1
# 649     GP   F   18       U          2         no       no         3       4
# 650     MS   F   16       R          2        yes      yes         4       4
#
# ...
