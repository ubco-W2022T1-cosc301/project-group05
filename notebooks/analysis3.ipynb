# %% [markdown]
# ## Research question/interests
#
# ***(I would like to note that for Milestone 3, I have changed my research question, and are located at the beginning of the milestone section within this analysis-notebook. I chose to keep these two questions here in case I wanted to ever go back and revise them)***
#
# #### Question 1
# What is the correlation between alcohol consumption and academic success?
#
# #### Question 2
# Given our data, what is the coorelation between the use of a student's freetime (studying, going out,  etc..) and absences?
#
# #### Interest
# I am interested in the correlation between what attributes are the main factors of success and failure for students. In particular, if the data will show a consistent trend between both of the courses.

# %% [markdown]
# #### Code:

# %%
# Importing pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#To get rid of warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading and displaying the CVS File for Math through path
df_math = pd.read_csv('../data/raw/Maths_formatted.csv', engine='python', on_bad_lines='skip')
display(df_math)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
# 395     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 396     MS   M   19       R     GT3       T     1     1     other  services
#
# ...

# %% [markdown]
# # Nils Kelley

# %%
# Reading and displaying the CVS File for Portuguese through path
df_portuguese = pd.read_csv('../data/raw/Portuguese_formatted.csv', engine='python', on_bad_lines='skip')
display(df_portuguese)

datframe_mrg = pd.merge(df_math, df_portuguese)
display(datframe_mrg)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
# 649     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 650     MS   F   16       R     GT3       T     2     2     other     other
#
# ...

# %% [markdown]
# **************************************************************************************************************************************
# # ***Milestone 3: Data Analysis***

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------
#
#                                                            RESEARCH QUESTIONS
# --------------------------------------------------------------------------------------------------------------------------------------
#
#
# ### Research Question 1: ***Given our data, what is the coorelation between alcohol consumption and academic results?***
# ### Research Question 2: ***Given our data, what is the coorelation between the use of a student's freetime (studying, going out,  etc..) and absences?***
# ### Research Question 3: ***Do any patterns emerge between the previously stated reserach questions? If so, what trends / findings do they indicate/show?***
#
# ##### In short, ***for this milestone, I will be analyzing the coorelation between a Math student's freetime, Alcohol use and final grades, while also keeping in mind their absences.***
#
# --------------------------------------------------------------------------------------------------------------------------------------
#                                                 Why Did I Change my Research Questions?
#
# #### I made the change because as my research went on, I realized that I was organically drawn to those aspects of the student's lives in regard to their final grades. I'm not completely sure why, but it was a natural transition of research questions and I feel it made me care more about the accuracy and results of the data.
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ***Milestone 3 - Task1:***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('../data/raw/Maths_formatted.csv', engine='python', on_bad_lines='skip')
df2 = pd.read_csv('../data/raw/Portuguese_formatted.csv', engine='python', on_bad_lines='skip')

plt.figure()
print("******************************************************************")
print("First four graphs are Math. Final four for Portuguese")
print("******************************************************************")
print("Portuguese Graps: (Graphs 1, 2, 3, 4")
print("Portuguese Graphs: (Graphs 5, 6, 7, 8)")
print("******************************************************************")

#Freetime X Absences (Math)
a = sns.histplot(data=df, x='freetime', y='absences')
a.set_title("Math - Freetime X Absences")
plt.show()
#Final Grade X Absences (Math)
b = sns.histplot(data=df, x='G3', y='absences')
b.set_title("Math - Final Grade X Absences")
plt.show()
#Freetime X Final Grade (Math)
c = sns.histplot(data=df, x='freetime', y='G3')
c.set_title("Math - Freetime X Final Grade")
plt.show()
#Weekend ALC Use X Absences (Math)
d = sns.histplot(data=df, x='Walc', y='absences')
d.set_title("Math - Weekend Alc Use X Absences")
plt.show()
#Weekend ALC use X Final Grade (Math)
q = sns.histplot(data=df, x='Walc', y='G3')
q.set_title("Math - Weekend Alc Use X Final Grade")
plt.show()

#Freetime X Absences (Portugese)
e = sns.histplot(data=df2, x='freetime', y='absences')
e.set_title("Portugese - Freetime X Absences")
plt.show()
#Final Grade X Absences (Portugese)
f = sns.histplot(data=df2, x='G3', y='absences')
f.set_title("Portugese - Final Grade X Absences")
plt.show()
#Freetime X Final Grade (Portugese)
g = sns.histplot(data=df2, x='freetime', y='G3')
g.set_title("Portugese - Freetime X Final Grade")
plt.show()
#Weekend ALC Use X Absences (Portugese)
h = sns.histplot(data=df2, x='Walc', y='absences')
h.set_title("Portugese - Weekend ALC use X Absences")
plt.show()
h.set_title("Portugese - Weekend Alc Use X Absences")
#Weekend ALC Use X Final Grade (Portugese)
i = sns.histplot(data=df2, x='Walc', y='G3')
i.set_title("Portugese - Weekend Alc Use X Final Grade")
plt.show()
# Out:
# ******************************************************************
# First four graphs are Math. Final four for Portuguese
# ******************************************************************
# Portuguese Graps: (Graphs 1, 2, 3, 4
# Portuguese Graphs: (Graphs 5, 6, 7, 8)
# ******************************************************************

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------
#
# #### ***Findings from EDA*** (Task 1):
# --------------------------------------------------------------------------------------------------------------------------------------
#                                     What Do The Findings Show? (2 Things)
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# (1) ***There is a correlation between the patterns of students between the two courses,*** AND

# %% [markdown]
# (2) ***That Less Absences <-> Less FreeTime <-> Higher G3(final grade) <-> Less Walc (weekend alcohol consumption)***

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------
#
# ## ***Milestone 3 -Task 2***: Set up an "Analysis Pipeline"
# --------------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import seaborn as sp
import matplotlib.pyplot as plt


# 1: Load Data
dfm = pd.read_csv('../data/raw/Maths_formatted.csv', engine='python', on_bad_lines='skip')
dfp = pd.read_csv('../data/raw/Portuguese_formatted.csv', engine='python', on_bad_lines='skip')

# 2&3: Cleaning through the Processing 
grouped = dfm.groupby('G3').mean()
grouped2 = dfp.groupby('G3').mean()

# Plotting Data to show what the distibution of things is for different varities of G3 (avg) for (1) - Math and (2) - Portuguese
plt.figure()
a = grouped.plot.barh(stacked=True)
a.set_title("Math - Distribution of Factors Vs Final Grade")
b = grouped2.plot.barh(stacked=True)
b.set_title("Portuguese - Distribution of Time Vs Final Grade")

# 4: Wrangling Data 
# fm = Highest and Lowest scoring students for Math
fm = pd.merge(dfm, grouped, how='inner')
display(fm)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu    Mjob      Fjob  ...  \
# 0     GP   M   16       U     GT3       T     4     3  health  services  ...
# 1     GP   F   17       U     GT3       T     4     3   other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        2      2     1     1      2        4  19  19  20
# 1      3        4      5     2     4      1       22   6   6   4
#
# [2 rows x 33 columns]

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------
#
# ## ***Milestone 3 - Task 3***: Method Chaining and Python Programs
#
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#                                 Explanation of Columns Added Through Method Chaining
# ### ***Use_Of_Freetime:***
#
# -Scaled from low, 1, to high, 10.
#
# -Illustrates the average use of study time in addition to a students respective freetime.
#
# -Added this as a means of establishing a basis to compare student's Final_Grade in the hopes of establishing a pattern.
#
#
# ### ***Weekly_Drinking_AVG:***
#
# -Scaled from 1, low, to 10, high.
#
# -It respresents the average of a student's weekday and weekend alc usage.

# %%
# Milestone 3 - Tasks 1 & 2
# Method Chaining - Function 
import pandas as pd

def load_and_process(url_or_path_to_csv_file):

    # Method Chain 1 (Load data and deal with missing data)
   
    # dropping col
    drop_col = ['traveltime','failures', 'nursery','guardian', 'Medu', 'Fedu', 'reason', 'schoolsup', 'famsup', 'paid','Fjob','Mjob', 'famrel', 'famsize', 'Pstatus'
        ,'higher', 'romantic', 'internet', 'address', 'activities']
    # renaming col
    ren = {'Walc': 'Weekend_Alc_Consumption', 'Dalc': 'Daily_Alc_Consumption', 'freetime': 'Freetime', 'goout': 'Go_Out',
    'age': 'Age', 'school':'School', 'sex': 'Sex', 'health': 'Health', 'absences': 'Absences', 'G1': 'Period_1_Grade', 
    'G2': 'Period_2_Grade', 'G3': 'Final_Grade', 'studytime': 'Study_Time'}
    # col to be sorted
    sort = ['Weekend_Alc_Consumption','Daily_Alc_Consumption','Freetime', 'Final_Grade']
    # rephrase value of col
    rep = {'F': 'Female', 'M': 'Male', 'GP': 'Gabriel Pereira', 'MS': 'Mousinho Da Silveira'}

    df1 = (   
    pd.read_csv(url_or_path_to_csv_file, engine='python', on_bad_lines='skip')
        .rename(columns=ren)
        .replace(rep)
        .drop(drop_col, axis=1)
        .sort_values(sort, ascending=False)
    )

    df2 = (
        df1
        .assign(Weekly_Drinking_AVG=df1['Weekend_Alc_Consumption']+df1['Daily_Alc_Consumption']/2)
        .assign(Use_Of_Freetime=df1['Freetime']+df1['Study_Time']+df1['Go_Out']/3)
    )

    return df2

load_and_process('../data/raw/Portuguese_formatted.csv')
# Out:
#                    School     Sex  Age  Study_Time  Freetime  Go_Out  \
# 61        Gabriel Pereira  Female   16           1         5       5
# 457  Mousinho Da Silveira    Male   17           1         5       5
# 576  Mousinho Da Silveira    Male   18           1         5       5
# 447  Mousinho Da Silveira    Male   17           1         5       5
# 100       Gabriel Pereira    Male   16           1         5       5
# ..                    ...     ...  ...         ...       ...     ...
# 264       Gabriel Pereira  Female   17           1         1       2
# 318       Gabriel Pereira  Female   18           2         1       1
# 425  Mousinho Da Silveira  Female   15           1         1       3
# 646  Mousinho Da Silveira  Female   18           2         1       1
# 255       Gabriel Pereira  Female   18           1         1       1
#
#      Daily_Alc_Consumption  Weekend_Alc_Consumption  Health  Absences  \
# ...

# %%
import pandas as pd
from project_functions3 import load_and_process
from project_functions3 import combine_subj

load_and_process('../data/raw/Portuguese_formatted.csv')

cleaned_data = combine_subj({'Math': load_and_process('../data/raw/Maths_formatted.csv'),'Portuguese': load_and_process('../data/raw/Portuguese_formatted.csv')})
cleaned_data
# Out:
#                     School     Sex  Age  Study_Time  Freetime  Go_Out  \
# 0     Mousinho Da Silveira    Male   18           1         5       5
# 1          Gabriel Pereira  Female   16           1         5       5
# 2          Gabriel Pereira    Male   16           1         5       5
# 3          Gabriel Pereira    Male   17           2         4       2
# 4          Gabriel Pereira    Male   16           2         4       5
# ...                    ...     ...  ...         ...       ...     ...
# 1043       Gabriel Pereira  Female   17           1         1       2
# 1044       Gabriel Pereira  Female   18           2         1       1
# 1045  Mousinho Da Silveira  Female   15           1         1       3
# 1046  Mousinho Da Silveira  Female   18           2         1       1
# 1047       Gabriel Pereira  Female   18           1         1       1
#
#       Daily_Alc_Consumption  Weekend_Alc_Consumption  Health  Absences  \
# ...

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------
# ## ***Miestone 3 - Task 4:*** Answering Research Questions Through Findings
# -------------------------------------------------------------------------------------------------------------------------------------
#
# ### Question 1: ***Given our data, what is the coorelation between alcohol consumption and academic results?***
#
#     Given the data, there was no clear indiciation between a student's alcohol usage and their academic success. This was evident with the student with the highest Final Grade (16) having a weekly drinking average of 7.5/10, while another student had a final grade of (8) and a weekly alcohol average of 7.5. There were also many student's that had low alcohol usages, such as 1.5, that also had low final grades, consistently ranging from 7-10. That being said, while the data might not necessarily show it, I do believe, that if we were to analyze a larger data set, such as, all students in a given province, that we would then see a clear pattern between an increased alcohol use resulting in a decrease in academic success.
#
# -------------------------------------------------------------------------------------------------------------------------------------
#
# ### Research Question 2: ***Given our data, what is the coorelation between the use of a student's freetime (studying, going out,  etc..) and absences?***
#
#     Given the data, there does not seem to be any clear indication between a students use of freetime and their absences. On the one hand, for example, the data shows some students that had a high use of freetime, such as, 7.5 / 10, indicating that they spend most of their freetime to study or go out in relation to the overall amount of freetime that they have, would still have absences of 10+, such as one student with the priorly stated use of freetime statistic having 12 absences. On the other hand, sseveral students with use of freetime averages of less than 4, indicating less studying, going out, and overall freetime can be found having more than 10 absences as well. Such as two students, who had 14 and 15 absences, while having a use of freetime of 2.3 and 3.3; both within the lower quartile. In a sense, this dataset does not tell us much about the correlation between freetime and absences, but I think it tells us a very important thing about high school students: No matter how busy they are, they will always find the time to skip class.
#
# -------------------------------------------------------------------------------------------------------------------------------------
#
# ### Research Question 3:  ***Given our data, what is the coorelation between the use of a student's freetime (studying, going out,  etc..) absences, and their final grade***
#
#     Yes! In a way at least. What I mean by this is that there is a clear pattern of students that have a higher use of freetime almost always have a higher weekly drinking average, and vice versa. In other words, students with more freetime and more likely to be drinking alcohol consistently throughout the week. In reality, this finding can likely be easily backed with psychological findings about how alcohol affects the user's brain and their priorization of their lives. To reiterate, I believe that this finding is likely the resultant of a loop in which students will create more freetime in the hopes of drinking more, which then in return makes them want to create more freetime. That being said, it should be restated from the first question, that this finding does not seem to have any correlation with the grade's of the student's as they seem to vary widely, likely resulting from a combination of factors, both within the data set, and outside of it.
#
# -------------------------------------------------------------------------------------------------------------------------------------

# %%
# Milestone 4

# Task 1 
cleaned_data.to_csv("../data/processed/clean_analysis3.csv")
